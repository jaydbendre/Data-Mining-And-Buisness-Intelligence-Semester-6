# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./Datasets/Clean/cleaned_dataset_train.csv")
data = pd.DataFrame(data)

# %%
data
# Out:
#              id  week  city_code  region_code  center_type  op_area  \
# 0       1379560     1        647           56            2      2.0
# 1       1018704     2        647           56            2      2.0
# 2       1196273     3        647           56            2      2.0
# 3       1116527     4        647           56            2      2.0
# 4       1343872     5        647           56            2      2.0
# ...         ...   ...        ...          ...          ...      ...
# 456543  1437396   141        473           77            0      4.5
# 456544  1060716   142        473           77            0      4.5
# 456545  1029231   143        473           77            0      4.5
# 456546  1141147   144        473           77            0      4.5
# 456547  1443704   145        473           77            0      4.5
#
#          category      cuisine  checkout_price  base_price  \
# 0       Beverages         Thai          136.83      152.29
# ...

# %%
data.head(15)
# Out:
#          id  week  city_code  region_code  center_type  op_area   category  \
# 0   1379560     1        647           56            2      2.0  Beverages
# 1   1018704     2        647           56            2      2.0  Beverages
# 2   1196273     3        647           56            2      2.0  Beverages
# 3   1116527     4        647           56            2      2.0  Beverages
# 4   1343872     5        647           56            2      2.0  Beverages
# 5   1493612     6        647           56            2      2.0  Beverages
# 6   1110832     7        647           56            2      2.0  Beverages
# 7   1461167     8        647           56            2      2.0  Beverages
# 8   1102364     9        647           56            2      2.0  Beverages
# 9   1018130    10        647           56            2      2.0  Beverages
# 10  1047565    11        647           56            2      2.0  Beverages
# ...

# %%
#Number of items across various categories
data["category"].value_counts()
# Out:
# Beverages       127890
# Rice Bowl        33408
# Sandwich         33291
# Pizza            33138
# Starters         29941
# Other Snacks     29379
# Desert           29294
# Salad            28559
# Pasta            27694
# Seafood          26916
# Biryani          20614
# Extras           13562
# Soup             12675
# Fish             10187
# Name: category, dtype: int64

# %%
#Number of different types of cuisines
data["cuisine"].value_counts()
# Out:
# Italian        122925
# Thai           118216
# Indian         112612
# Continental    102795
# Name: cuisine, dtype: int64

# %%
#Finding coorelation between numerical attributes using the pearson's coefficient
cor = data.corr(method="pearson")
cor
# Out:
#                              id      week  city_code  region_code  \
# id                     1.000000  0.002225  -0.000387    -0.000648
# week                   0.002225  1.000000   0.000405     0.004600
# city_code             -0.000387  0.000405   1.000000     0.042686
# region_code           -0.000648  0.004600   0.042686     1.000000
# center_type            0.000473  0.000049   0.091500    -0.009658
# op_area               -0.000090  0.001550   0.131476     0.023327
# checkout_price         0.001941  0.026581  -0.004805    -0.003648
# base_price             0.002909  0.028614  -0.002054    -0.001934
# emailer_for_promotion  0.002001 -0.000841  -0.005234    -0.007462
# homepage_featured      0.003111 -0.008263   0.008640     0.003605
# num_orders             0.000702 -0.017210   0.041596     0.029744
#
#                        center_type   op_area  checkout_price  base_price  \
# id                        0.000473 -0.000090        0.001941    0.002909
# ...

# %%
table = pd.crosstab(data["region_code"],data["category"])
table
# Out:
# category     Beverages  Biryani  Desert  Extras  Fish  Other Snacks  Pasta  \
# region_code
# 23                1684      215     378     416   160           415    351
# 34               34545     5331    8201       0  2959          7691   7640
# 35                1668      157     322       0   190           211    290
# 56               50032     8732   11411   11491  4138         11892  11026
# 71                1713      291     386      89   158           425    352
# 77               28535     4373    6441       0  1937          6414   6145
# 85                8011     1263    1767    1566   395          1961   1499
# 93                1702      252     388       0   250           370    391
#
# category     Pizza  Rice Bowl  Salad  Sandwich  Seafood  Soup  Starters
# region_code
# 23             426        435    370       434      366   416       368
# 34            9076       9132   7890      9126     7013     0      8109
# ...

# %%
table = pd.crosstab(data["city_code"],data["category"])
table
# Out:
# category   Beverages  Biryani  Desert  Extras  Fish  Other Snacks  Pasta  \
# city_code
# 456             1684      342     391     415   159           417    392
# 461             1712      221     403       0   233           357    385
# 473             1709      324     377       0   172           423    373
# 478             1586      150     374       0     0           373    314
# 485             1715      294     391       0   142           367    391
# 515             1681      179     342       0     0           354    334
# 517             3350      629     786     870   247           840    774
# 522             3371      651     807     844   341           848    780
# 526            12961     1956    3164       0   993          2805   2864
# 541             1543       81     354       0     0            45    267
# 553             1677      260     374       0    35           435    360
# 556             1686      334     393       0   158           409    381
# ...

# %%
#printing various statistics of num_orders
data["num_orders"].describe()
# Out:
# count    456548.000000
# mean        261.872760
# std         395.922798
# min          13.000000
# 25%          54.000000
# 50%         136.000000
# 75%         324.000000
# max       24299.000000
# Name: num_orders, dtype: float64

# %%
#printing various statistics of checkout_price
data["checkout_price"].describe()
# Out:
# count    456548.000000
# mean        332.238933
# std         152.939723
# min           2.970000
# 25%         228.950000
# 50%         296.820000
# 75%         445.230000
# max         866.270000
# Name: checkout_price, dtype: float64

# %%
#printing various statistics of base_price
data["base_price"].describe()
# Out:
# count    456548.000000
# mean        354.156627
# std         160.715914
# min          55.350000
# 25%         243.500000
# 50%         310.460000
# 75%         458.870000
# max         866.270000
# Name: base_price, dtype: float64

# %%
#grouping num_orders based on type of cuisine and the category and printing the describe function
grouped_data=data.groupby(["cuisine","category"])["num_orders"]
grouped_data.describe()
# Out:
#                             count        mean         std   min    25%    50%  \
# cuisine     category
# Continental Beverages     32554.0  182.559624  162.068478  13.0   81.0  148.0
#             Fish          10187.0   85.595268   80.303895  13.0   28.0   67.0
#             Pizza         33138.0  222.817309  227.976970  13.0   82.0  149.0
#             Seafood       26916.0  100.895898  137.335619  13.0   27.0   54.0
# Indian      Beverages     29296.0   80.075061   88.400720  13.0   28.0   54.0
#             Biryani       20614.0   30.651402   22.092493  13.0   14.0   26.0
#             Desert        29294.0   66.250905   60.239531  13.0   27.0   53.0
#             Rice Bowl     33408.0  624.822288  745.306184  13.0  258.0  433.0
# Italian     Beverages     33381.0  418.021329  339.564139  13.0  189.0  323.0
#             Pasta         27694.0   59.137142   54.081742  13.0   26.0   42.0
#             Salad         28559.0  383.218460  353.131091  13.0  190.0  298.0
# ...
